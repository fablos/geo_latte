# %%
import numpy as np
from core import utils, geodesics, geometric_methods, manifolds
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
# Generate the data
params = {'N': 200, 'data_type': 1, 'sigma': 0.1}
data = utils.generate_data(params)

# %%
# Construct the manifold
manifold = manifolds.LocalDiagPCA(data=data, sigma=0.15, rho=1e-2)

# %%
# Plot the Riemannian volume element
utils.plot_measure(manifold, np.linspace(-1.5, 1.5, 100), np.linspace(-0.5, 1.5, 100))
utils.my_plot(data, c='k', s=10)
plt.axis('image')
plt.pause(0.1)
plt.show()

# %%
# Plot the Riemannian volume element
utils.plot_measure(manifold, np.linspace(-1.5, 1.5, 100), np.linspace(-0.5, 1.5, 100))
utils.my_plot(data, c='k', s=10)
plt.axis('image')
plt.pause(0.1)

# Prepare the solver
solver = geodesics.SolverBVP(NMax=100, tol=1e-1)

# Fit the LAND model
LAND_DATA = KMeans(n_clusters=60).fit(data).cluster_centers_
params = {}
params['means'] = KMeans(n_clusters=2).fit(data).cluster_centers_
params['K'] = 2
params['S'] = 100
params['max_iter'] = 10
params['tol'] = 0.1
params['step_size'] = 0.1
params['mixing_param'] = 0  # [0, 1] how much between empirical covariance and identity
land_res_prior = geometric_methods.land_mixture_model(manifold=manifold,
                                                      solver=solver,
                                                      data=LAND_DATA,
                                                      param=params)
# Out:
# [Initialize: 1/2] [Process point: 1/60]
# Geodesic solver (bvp) failed!
# [Initialize: 1/2] [Process point: 2/60]
# [Initialize: 1/2] [Process point: 3/60]
# [Initialize: 1/2] [Process point: 4/60]
# [Initialize: 1/2] [Process point: 5/60]
# [Initialize: 1/2] [Process point: 6/60]
# [Initialize: 1/2] [Process point: 7/60]
# [Initialize: 1/2] [Process point: 8/60]
# [Initialize: 1/2] [Process point: 9/60]
# [Initialize: 1/2] [Process point: 10/60]
# [Initialize: 1/2] [Process point: 11/60]
# Geodesic solver (bvp) failed!
# [Initialize: 1/2] [Process point: 12/60]
# [Initialize: 1/2] [Process point: 13/60]
# [Initialize: 1/2] [Process point: 14/60]
# [Initialize: 1/2] [Process point: 15/60]
# [Initialize: 1/2] [Process point: 16/60]
# [Initialize: 1/2] [Process point: 17/60]
# Geodesic solver (bvp) failed!
# [Initialize: 1/2] [Process point: 18/60]
# [Initialize: 1/2] [Process point: 19/60]
# [Initialize: 1/2] [Process point: 20/60]
# [Initialize: 1/2] [Process point: 21/60]
# [Initialize: 1/2] [Process point: 22/60]
# Geodesic solver (bvp) failed!
# [Initialize: 1/2] [Process point: 23/60]
# [Initialize: 1/2] [Process point: 24/60]
# [Initialize: 1/2] [Process point: 25/60]
# Geodesic solver (bvp) failed!
# [Initialize: 1/2] [Process point: 26/60]
# [Initialize: 1/2] [Process point: 27/60]
# [Initialize: 1/2] [Process point: 28/60]
# [Initialize: 1/2] [Process point: 29/60]
# [Initialize: 1/2] [Process point: 30/60]
# Geodesic solver (bvp) failed!
# [Initialize: 1/2] [Process point: 31/60]
# Geodesic solver (bvp) failed!
# [Initialize: 1/2] [Process point: 32/60]
# [Initialize: 1/2] [Process point: 33/60]
# Geodesic solver (bvp) failed!
# [Initialize: 1/2] [Process point: 34/60]
# [Initialize: 1/2] [Process point: 35/60]
# Geodesic solver (bvp) failed!
# [Initialize: 1/2] [Process point: 36/60]
# Geodesic solver (bvp) failed!
# [Initialize: 1/2] [Process point: 37/60]
# [Initialize: 1/2] [Process point: 38/60]
# [Initialize: 1/2] [Process point: 39/60]
# [Initialize: 1/2] [Process point: 40/60]
# [Initialize: 1/2] [Process point: 41/60]
# Geodesic solver (bvp) failed!
# [Initialize: 1/2] [Process point: 42/60]
# [Initialize: 1/2] [Process point: 43/60]
# [Initialize: 1/2] [Process point: 44/60]
# [Initialize: 1/2] [Process point: 45/60]
# [Initialize: 1/2] [Process point: 46/60]
# Geodesic solver (bvp) failed!
# [Initialize: 1/2] [Process point: 47/60]
# Geodesic solver (bvp) failed!
# [Initialize: 1/2] [Process point: 48/60]
# [Initialize: 1/2] [Process point: 49/60]
# [Initialize: 1/2] [Process point: 50/60]
# Geodesic solver (bvp) failed!
# [Initialize: 1/2] [Process point: 51/60]
# [Initialize: 1/2] [Process point: 52/60]
# [Initialize: 1/2] [Process point: 53/60]
# [Initialize: 1/2] [Process point: 54/60]
# [Initialize: 1/2] [Process point: 55/60]
# [Initialize: 1/2] [Process point: 56/60]
# [Initialize: 1/2] [Process point: 57/60]
# [Initialize: 1/2] [Process point: 58/60]
# [Initialize: 1/2] [Process point: 59/60]
# Geodesic solver (bvp) failed!
# [Initialize: 1/2] [Process point: 60/60]
# [Initialize: 2/2] [Process point: 1/60]
# [Initialize: 2/2] [Process point: 2/60]
# [Initialize: 2/2] [Process point: 3/60]
# Geodesic solver (bvp) failed!
# [Initialize: 2/2] [Process point: 4/60]
# [Initialize: 2/2] [Process point: 5/60]
# [Initialize: 2/2] [Process point: 6/60]
# [Initialize: 2/2] [Process point: 7/60]
# [Initialize: 2/2] [Process point: 8/60]
# Geodesic solver (bvp) failed!
# [Initialize: 2/2] [Process point: 9/60]
# [Initialize: 2/2] [Process point: 10/60]
# [Initialize: 2/2] [Process point: 11/60]
# [Initialize: 2/2] [Process point: 12/60]
# Geodesic solver (bvp) failed!
# [Initialize: 2/2] [Process point: 13/60]
# [Initialize: 2/2] [Process point: 14/60]
# [Initialize: 2/2] [Process point: 15/60]
# [Initialize: 2/2] [Process point: 16/60]
# Geodesic solver (bvp) failed!
# [Initialize: 2/2] [Process point: 17/60]
# [Initialize: 2/2] [Process point: 18/60]
# Geodesic solver (bvp) failed!
# [Initialize: 2/2] [Process point: 19/60]
# Geodesic solver (bvp) failed!
# [Initialize: 2/2] [Process point: 20/60]
# Geodesic solver (bvp) failed!
# [Initialize: 2/2] [Process point: 21/60]
# Geodesic solver (bvp) failed!
# [Initialize: 2/2] [Process point: 22/60]
# [Initialize: 2/2] [Process point: 23/60]
# [Initialize: 2/2] [Process point: 24/60]
# [Initialize: 2/2] [Process point: 25/60]
# [Initialize: 2/2] [Process point: 26/60]
# [Initialize: 2/2] [Process point: 27/60]
# Geodesic solver (bvp) failed!
# [Initialize: 2/2] [Process point: 28/60]
# Geodesic solver (bvp) failed!
# [Initialize: 2/2] [Process point: 29/60]
# [Initialize: 2/2] [Process point: 30/60]
# [Initialize: 2/2] [Process point: 31/60]
# [Initialize: 2/2] [Process point: 32/60]
# Geodesic solver (bvp) failed!
# [Initialize: 2/2] [Process point: 33/60]
# [Initialize: 2/2] [Process point: 34/60]
# Geodesic solver (bvp) failed!
# [Initialize: 2/2] [Process point: 35/60]
# [Initialize: 2/2] [Process point: 36/60]
# [Initialize: 2/2] [Process point: 37/60]
# Geodesic solver (bvp) failed!
# [Initialize: 2/2] [Process point: 38/60]
# [Initialize: 2/2] [Process point: 39/60]
# Geodesic solver (bvp) failed!
# [Initialize: 2/2] [Process point: 40/60]
# [Initialize: 2/2] [Process point: 41/60]
# [Initialize: 2/2] [Process point: 42/60]
# [Initialize: 2/2] [Process point: 43/60]
# [Initialize: 2/2] [Process point: 44/60]
# [Initialize: 2/2] [Process point: 45/60]
# [Initialize: 2/2] [Process point: 46/60]
# [Initialize: 2/2] [Process point: 47/60]
# [Initialize: 2/2] [Process point: 48/60]
# [Initialize: 2/2] [Process point: 49/60]
# Geodesic solver (bvp) failed!
# [Initialize: 2/2] [Process point: 50/60]
# [Initialize: 2/2] [Process point: 51/60]
# [Initialize: 2/2] [Process point: 52/60]
# [Initialize: 2/2] [Process point: 53/60]
# Geodesic solver (bvp) failed!
# [Initialize: 2/2] [Process point: 54/60]
# [Initialize: 2/2] [Process point: 55/60]
# Geodesic solver (bvp) failed!
# [Initialize: 2/2] [Process point: 56/60]
# [Initialize: 2/2] [Process point: 57/60]
# [Initialize: 2/2] [Process point: 58/60]
# Geodesic solver (bvp) failed!
# [Initialize: 2/2] [Process point: 59/60]
# [Initialize: 2/2] [Process point: 60/60]
# [Iteration: 1/10] [Negative log-likelihood: 196.86850060224998]
# [Updating mean: 1] [Iteration: 1/10]
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# [Updating mean: 2] [Iteration: 1/10]
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# [Updating Sigma: 1] [Iteration: 1/10]
# [Updating Sigma: 2] [Iteration: 1/10]
# [Iteration: 2/10] [Negative log-likelihood: 187.74720988895916]
# [Updating mean: 1] [Iteration: 1/10]
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# [Updating mean: 2] [Iteration: 1/10]
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# [Updating Sigma: 1] [Iteration: 1/10]
# [Updating Sigma: 2] [Iteration: 1/10]
# [Iteration: 3/10] [Negative log-likelihood: 191.48917219415486]
# [Updating mean: 1] [Iteration: 1/10]
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# [Updating mean: 2] [Iteration: 1/10]
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# [Updating Sigma: 1] [Iteration: 1/10]
# [Updating Sigma: 2] [Iteration: 1/10]
# [Iteration: 4/10] [Negative log-likelihood: 182.58745325201684]
# [Updating mean: 1] [Iteration: 1/10]
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# [Updating mean: 2] [Iteration: 1/10]
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# [Updating Sigma: 1] [Iteration: 1/10]
# [Updating Sigma: 2] [Iteration: 1/10]

# %%
# Plot the density
z1min, z2min = data.min(0) - 0.5
z1max, z2max = data.max(0) + 0.5
N_Z_grid = 20
Z_grid = utils.my_meshgrid(z1min, z1max, z2min, z2max, N=N_Z_grid)
Logmaps = np.zeros((2, Z_grid.shape[0], data.shape[1]))  # The logmaps for each center
for k in range(2):
    for n in range(Z_grid.shape[0]):
        # If the solver fails then the logmap is overestimated (straight line)
        curve_bvp, logmap_bvp, curve_length_bvp, failed_bvp, solution_bvp \
            = geodesics.compute_geodesic(solver, manifold,
                                         land_res_prior['means'][k, :].reshape(-1, 1),
                                         Z_grid[n, :].reshape(-1, 1))
        Logmaps[k, n, :] = logmap_bvp.ravel()

pdf_vals = np.zeros((Z_grid.shape[0], 1))
for k in range(2):
    pdf_vals += land_res_prior['Weights'][k, 0] * (np.exp(-0.5 * np.diag(Logmaps[k, :, :] @ np.linalg.inv(land_res_prior['Sigmas'][k, :, :]) @ Logmaps[k, :, :].T)) / land_res_prior['Consts'][k, 0]).reshape(-1, 1)
plt.imshow(pdf_vals.reshape(N_Z_grid, N_Z_grid), interpolation='bicubic', extent=(z1min, z1max, z2min, z2max), origin='lower')
# Out:
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# /home/fabris/wok/geo_latte/core/geodesics.py:132: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   curve_length_eval = integrate.quad(lambda t: local_length(manifold, curve, t), a, b, epsabs=tol, limit=limit)  # , number of subintervals
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
# Geodesic solver (bvp) failed!
